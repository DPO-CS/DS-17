# %% [markdown]
# # Практика. API Headhunter

# %% [markdown]
# Проведем анализ вакансий для Data Science. Документация API hh: https://api.hh.ru/openapi/redoc

# %%
import requests
from bs4 import BeautifulSoup
import json
from tqdm import tqdm
import numpy as np
import pandas as pd
from time import sleep
from collections import Counter

# %% [markdown]
# Запросы к API всегда выстраиваются в таком формате:
#
# URL API + нужный раздел + API-ключ (по требованию) + параметры
#
# https://api.hh.ru/vacancies?industry=47&only_with_salary=true&per_page=100&area=113&period=1&page=1
#
# Что в этом запросе?
#
# `https://api.hh.ru/vacancies` – запрос к БД с вакансиями \
# `?industry=47` – прицепляем с помощью **?** первый параметр `industry` с поиском по отрасли (id отрасли взят из справочника в документации), 47 = Нефть и газ \
# `&only_with_salary=true` – все следующие параметры прицепляем через **&**. Ищем вакансии только с указанной з/п \
# `&area=113` – только Россия (id страны взят из справочника в документации) \
# `&period=1` – вакансии за 1 день \
# `&page=1` – страница \
# `&per_page=100` – выводим на страницу 100 вакансий

# %%
vacancies = []

for i in range(0, 2):
    vac = requests.get(f"https://api.hh.ru/vacancies?text=data%20science&only_with_salary=true&per_page=100&page={i}")
    vacancies.extend(json.loads(vac.text)['items'])

# %%
vacancies[0]
# Out:
# {'id': '98772582',
#  'premium': False,
#  'name': 'Junior Data Scientist',
#  'department': None,
#  'has_test': True,
#  'response_letter_required': False,
#  'area': {'id': '2',
#   'name': 'Санкт-Петербург',
#   'url': 'https://api.hh.ru/areas/2'},
#  'salary': {'from': 1500, 'to': None, 'currency': 'USD', 'gross': False},
#  'type': {'id': 'open', 'name': 'Открытая'},
#  'address': None,
#  'response_url': None,
#  'sort_point_distance': None,
#  'published_at': '2024-05-13T10:29:24+0300',
#  'created_at': '2024-05-13T10:29:24+0300',
#  'archived': False,
#  'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=98772582',
#  'show_logo_in_search': None,
#  'insider_interview': None,
#  'url': 'https://api.hh.ru/vacancies/98772582?host=hh.ru',
#  'alternate_url': 'https://hh.ru/vacancy/98772582',
#  'relations': [],
#  'employer': {'id': '4055097',
#   'name': 'BlockShop',
#   'url': 'https://api.hh.ru/employers/4055097',
#   'alternate_url': 'https://hh.ru/employer/4055097',
#   'logo_urls': {'90': 'https://img.hhcdn.ru/employer-logo/3293780.png',
#    '240': 'https://img.hhcdn.ru/employer-logo/3293781.png',
#    'original': 'https://img.hhcdn.ru/employer-logo-original/713166.png'},
#   'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=4055097',
#   'accredited_it_employer': False,
#   'trusted': True},
#  'snippet': {'requirement': 'Prompt engineering for synthetic <highlighttext>data</highlighttext> generation. - MS Azure Notebooks (JavaScript). - Cloudflare Workers ecosystem (TypeScript). - Postgres-based time series and vector...',
#   'responsibility': 'Integrating and improving 3rd-party tools for Quality Assurance. - Contributing to scientific articles on natural language processing. Tools. - '},
#  'contacts': None,
#  'schedule': {'id': 'remote', 'name': 'Удаленная работа'},
#  'working_days': [],
#  'working_time_intervals': [{'id': 'from_four_to_six_hours_in_a_day',
#    'name': 'Можно работать сменами по\xa04–6 часов в\xa0день'}],
#  'working_time_modes': [{'id': 'start_after_sixteen',
#    'name': 'Можно начинать работать после 16:00'}],
#  'accept_temporary': True,
#  'professional_roles': [{'id': '165', 'name': 'Дата-сайентист'}],
#  'accept_incomplete_resumes': True,
#  'experience': {'id': 'noExperience', 'name': 'Нет опыта'},
billing_type': {'id': 'standard', 'name': 'Стандарт'},
#  'relations': [],
#  'name': 'Junior Backend Developer (Java)',
#  'insider_interview': None,
#  'response_letter_required': False,
#  'area': {'id': '2',
#   'name': 'Санкт-Петербург',
#   'url': 'https://api.hh.ru/areas/2?host=hh.ru'},
#  'salary': {'from': 60000, 'to': 120000, 'currency': 'RUR', 'gross': True},
#  'type': {'id': 'open', 'name': 'Открытая'},
#  'address': {'city': 'Санкт-Петербург',
#   'street': 'Аптекарский проспект',
#   'building': '4',
#   'lat': 59.969533,
#   'lng': 30.318276,
#   'description': None,
#   'raw': 'Санкт-Петербург, Аптекарский проспект, 4',
#   'metro': {'station_name': 'Петроградская',
#    'line_name': 'Московско-Петроградская',
#    'station_id': '15.215',
#    'line_id': '15',
#    'lat': 59.966389,
#    'lng': 30.311293},
#   'metro_stations': [{'station_name': 'Петроградская',
#     'line_name': 'Московско-Петроградская',
#     'station_id': '15.215',
#     'line_id': '15',
#     'lat': 59.966389,
#     'lng': 30.311293}]},
#  'allow_messages': True,
#  'experience': {'id': 'noExperience', 'name': 'Нет опыта'},
#  'schedule': {'id': 'flexible', 'name': 'Гибкий график'},
#  'employment': {'id': 'full', 'name': 'Полная занятость'},
#  'department': None,
#  'contacts': None,
#  'description': '<p>Мы IT-компания из Санкт-Петербурга, которая занимается разработкой мобильных приложений, веб-порталов, высоконагруженных сервисов, облачных решений, Gamedev-проектов и Data Science. Мы активно развиваемся, в нашей команде уже более 100 человек.</p> <p>Сейчас мы ищем <strong>Java разработчика,</strong> который хочет участвовать в интересных проектах, прокачивать свои навыки и расти вместе с нами.</p> <p> </p> <p><strong>Обязанности:</strong></p> <ul> <li>Разработка backend-программного обеспечения для веб-сайтов и мобильных приложений</li> <li>Проектирование и реализация баз данных MySQL / SQLite / PostgreSQL</li> <li>Проектирование и разработка REST API</li> </ul> <p><strong>Требования:</strong></p> <ul> <li>Умение работать с Java и фреймоворком Spring</li> <li>Умение работать с MySQL / PostgreSQL, REST API</li> </ul> <p><strong>Условия:</strong></p> <ul> <li>Гибкий график (согласовывается индивидуально)</li> <li>Решение интересных задач</li> <li>Работа в молодой команде</li> <li>Развитие профессиональных навыков в интересующем Вас направлении</li> <li>Рост заработной платы по мере повышения квалификации</li> </ul>',
#  'branded_description': None,
#  'vacancy_constructor_template': None,
#  'key_skills': [{'name': 'Java SE'},
#   {'name': 'Spring Framework'},
#   {'name': 'PostgreSQL'},
#   {'name': 'ООП'}],
#  'accept_handicapped': True,
#  'accept_kids': False,
#  'archived': False,
#  'response_url': None,
#  'specializations': [],
#  'professional_roles': [{'id': '96', 'name': 'Программист, разработчик'}],
#  'code': None,
#  'hidden': False,
#  'quick_responses_allowed': False,
#  'driver_license_types': [],
#  'accept_incomplete_resumes': False,
#  'employer': {'id': '3495295',
#   'name': 'СИКСХЭНДС',
#   'url': 'https://api.hh.ru/employers/3495295?host=hh.ru',
#   'alternate_url': 'https://hh.ru/employer/3495295',
#   'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/679492.png',
#    '240': 'https://hhcdn.ru/employer-logo/3159101.png',
#    '90': 'https://hhcdn.ru/employer-logo/3159100.png'},
#   'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3495295&host=hh.ru',
#   'accredited_it_employer': False,
#   'trusted': True},
#  'published_at': '2023-11-17T14:23:37+0300',
#  'created_at': '2023-11-17T14:23:37+0300',
#  'initial_created_at': '2023-11-17T14:23:37+0300',
#  'negotiations_url': None,
#  'suitable_resumes_url': None,
#  'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=89601541',
#  'has_test': False,
#  'test': None,
#  'alternate_url': 'https://hh.ru/vacancy/89601541',
#  'working_days': [],
#  'working_time_intervals': [],
#  'working_time_modes': [],
#  'accept_temporary': True,
#  'languages': []}

# %%
test0['description']
# Out:
# '<p>Мы IT-компания из Санкт-Петербурга, которая занимается разработкой мобильных приложений, веб-порталов, высоконагруженных сервисов, облачных решений, Gamedev-проектов и Data Science. Мы активно развиваемся, в нашей команде уже более 100 человек.</p> <p>Сейчас мы ищем <strong>Java разработчика,</strong> который хочет участвовать в интересных проектах, прокачивать свои навыки и расти вместе с нами.</p> <p> </p> <p><strong>Обязанности:</strong></p> <ul> <li>Разработка backend-программного обеспечения для веб-сайтов и мобильных приложений</li> <li>Проектирование и реализация баз данных MySQL / SQLite / PostgreSQL</li> <li>Проектирование и разработка REST API</li> </ul> <p><strong>Требования:</strong></p> <ul> <li>Умение работать с Java и фреймоворком Spring</li> <li>Умение работать с MySQL / PostgreSQL, REST API</li> </ul> <p><strong>Условия:</strong></p> <ul> <li>Гибкий график (согласовывается индивидуально)</li> <li>Решение интересных задач</li> <li>Работа в молодой команде</li> <li>Развитие профессиональных навыков в интересующем Вас направлении</li> <li>Рост заработной платы по мере повышения квалификации</li> </ul>'

# %%
test0['key_skills']
# Out:
# [{'name': 'Java SE'},
#  {'name': 'Spring Framework'},
#  {'name': 'PostgreSQL'},
#  {'name': 'ООП'}]

# %%
[i['name'] for i in test0['key_skills']]
# Out:
# ['Java SE', 'Spring Framework', 'PostgreSQL', 'ООП']

# %% [markdown]
# Соберем в одну таблицу.

# %%
info = []

for l in tqdm(links):
    v = requests.get(l)
    v_loaded = json.loads(v.text)
    
    if v_loaded['salary']['currency'] == 'RUR':
    
        descr = v_loaded['description']
        skills = [i['name'] for i in v_loaded['key_skills']]
        money_from = v_loaded['salary'].get('from', np.nan)
        money_to = v_loaded['salary'].get('to', np.nan)
        url = v_loaded['alternate_url']

        info.append([descr, skills, money_from, money_to, url])
        sleep(3)
# Out:
# 100%|█████████████████████████████████████████| 163/163 [06:29<00:00,  2.39s/it]

# %%
df = pd.DataFrame(info, columns=['description', 'key_skills', 'salary_from', 'salary_to', 'url'])

# %%
df
# Out:
#                                            description  \
# 0    <p>Мы IT-компания из Санкт-Петербурга, которая...
# 1    <p>Мы создали<strong> RANKS.pro</strong> — Сис...
# 2    <p><em><strong>IDF Eurasia </strong></em>специ...
# 3    <p><strong>Karpov.courses </strong>— молодая E...
# 4    <strong>O2 Trading - ищем, проверяем, внедряем...
# ..                                                 ...
# 117  <p>Pygmalion AI — это передовая AI-платформа д...
# 118  <p>Pygmalion AI — это передовая AI-платформа д...
# 119  <p><strong>Про нас:</strong></p> <p>OTUS сегод...
# 120  <p>Pygmalion AI — это передовая AI-платформа д...
# 121  <p>Pygmalion AI — это передовая AI-платформа д...
#
#                                             key_skills  salary_from  \
# 0         [Java SE, Spring Framework, PostgreSQL, ООП]    60,000.00
# 1    [Python, Математическая статистика, SQL, Panda...    50,000.00
# 2                                                   []    40,000.00
# 3    [Документооборот, Работа с большим объемом инф...    50,000.00
# 4    [Python, SQL, Анализ данных, Работа с большим ...    40,000.00
# ..                                                 ...          ...
# 117  [Python, Аналитическое мышление, Data Analysis...   400,000.00
# 118  [Python, Аналитическое мышление, Data Analysis...   400,000.00
# 119  [Расчет заработной платы, Расчет зарплаты, Бух...          NaN
# 120  [Python, Аналитическое мышление, Data Analysis...   400,000.00
# 121  [Python, Аналитическое мышление, Data Analysis...   400,000.00
#
#      salary_to                             url
# 0   120,000.00  https://hh.ru/vacancy/89601541
# 1   100,000.00  https://hh.ru/vacancy/89380163
# 2          NaN  https://hh.ru/vacancy/87623047
# 3          NaN  https://hh.ru/vacancy/89215196
# 4   100,000.00  https://hh.ru/vacancy/89072255
# ..         ...                             ...
# 117        NaN  https://hh.ru/vacancy/88412207
# 118        NaN  https://hh.ru/vacancy/88412212
# 119  80,000.00  https://hh.ru/vacancy/89142460
# 120        NaN  https://hh.ru/vacancy/88412209
# 121        NaN  https://hh.ru/vacancy/88412210
#
# [122 rows x 5 columns]

# %%
df['key_skills'].sum()
# Out:
# ['Java SE',
#  'Spring Framework',
#  'PostgreSQL',
#  'ООП',
#  'Python',
#  'Математическая статистика',
#  'SQL',
#  'Pandas',
#  'Машинное обучение',
#  'Документооборот',
#  'Работа с большим объемом информации',
#  'Деловая переписка',
#  'Грамотная речь',
#  'amoCRM',
#  'Делопроизводство',
#  'Электронный документооборот',
#  'Python',
#  'SQL',
#  'Анализ данных',
#  'Работа с большим объемом информации',
#  'Базы данных',
#  'Аналитическое мышление',
#  'Работа с базами данных',
#  'Математическая статистика',
#  'Python',
#  'PostgreSQL',
#  'Docker',
#  'SQL',
#  'Git',
#  'FastAPI',
#  'Backend',
#  'MS SQL',
#  'Базы данных',
#  'ООП',
#  'SOLID',
#  'Работа в команде',
#  'Грамотная речь',
#  'Телефонные переговоры',
#  'Работа с базами данных',
#  'Ориентация на результат',
#  'Git',
#  'Java Core',
#  'Spring',
#  'Java',
#  'Hibernate',
#  'Apache Maven',
#  'PostgreSQL',
#  'Hibernate ORM',
#  'Web',
#  'MySQL',
#  'MongoDB',
#  'Linux',
#  'ООП',
#  'Teamplayer',
#  'Time management',
#  'Negotiation skills',
#  'Analytical skills',
#  'Sales Skills',
#  'JavaScript',
#  'Bootstrap',
#  'Git',
#  'AngularJS',
#  'Верстка',
#  'HTML',
#  'CSS',
#  'Linux',
#  'React.js',
#  'Vue.js',
#  'Английский язык',
#  'Аналитические исследования',
#  'Социологические исследования',
#  'Stata',
#  'R',
#  'Python',
#  'ML',
#  'Big Data',
#  'NLP',
#  'эконометрика',
#  'Legal tech',
#  'Legal design',
#  'разметка текстов',
#  'Google colaboratory',
#  'административные данные',
#  'судебная статистика',
#  'Swift',
#  'Git',
#  'iOS',
#  'REST',
#  'UIKit',
#  'Аналитические исследования',
#  'Анализ данных',
#  'AI',
#  'Английский язык',
#  'Грамотность',
#  'Бизнес-анализ',
#  'Сбор и анализ информации',
#  'Android',
#  'Java',
#  'Kotlin',
#  'Git',
#  'Английский — A2 — Элементарный',
#  'Power BI',
#  'Teradata',
#  'SQL-запросы',
#  'Python',
#  'Анализ данных',
#  'Machine Learning',
#  'NLP',
#  'Английский язык',
#  'Аналитическое мышление',
#  'Сбор и анализ информации',
#  'Английский язык',
#  'Аналитические исследования',
#  'Подготовка презентаций',
#  'Экономический анализ',
#  'Python',
#  'SQL',
#  'Анализ данных',
#  'Работа с большим объемом информации',
#  'Базы данных',
#  'Аналитическое мышление',
#  'Работа с базами данных',
#  'Математическая статистика',
#  'Adobe Illustrator',
#  'Figma',
#  'Дизайн',
#  'PHP',
#  'Linux',
#  'Git',
#  'ООП',
#  'MySQL',
#  'Golang',
#  'Бизнес-анализ',
#  'SQL',
#  'MS PowerPoint',
#  'Power BI',
#  'BPMN',
#  'Оптимизация бизнес-процессов',
#  'Работа с большим объемом информации',
#  'Поиск информации в интернет',
#  'Организаторские навыки',
#  'Python',
#  'SQL',
#  'Анализ данных',
#  'Работа с большим объемом информации',
#  'Базы данных',
#  'Аналитическое мышление',
#  'Работа с базами данных',
#  'Математическая статистика',
#  'Python',
#  'PostgreSQL',
#  'Flask',
#  'SQL',
#  'FastAPI',
#  'Redis',
#  'ClickHouse',
#  'Backend',
#  'Trino',
#  'Проведение презентаций',
#  'продажа рекламных продуктов',
#  'B2B Продажи',
#  'Продвижение бренда',
#  'Проектирование обучения',
#  'E-Learning',
#  'Таксономия Блума',
#  'Таксономия Марцано',
#  'Цикл Гиббса',
#  '4C/ID',
#  'Разработка технических заданий',
#  'Аналитическое мышление',
#  'UML',
#  'BPMN',
#  'Python',
#  'Spark',
#  'SQL',
#  'Machine Learning',
#  'Pandas',
#  'Машинное обучение',
#  'Data Science',
#  'Big Data',
#  'PySpark',
#  'Hive',
#  'Анализ данных',
#  'Data Analysis',
#  'ML',
#  'Hadoop',
#  'Python',
#  'Linux',
#  'ООП',
#  'C++',
#  'SQL',
#  'Интернет-реклама',
#  'Поиск и привлечение клиентов',
#  'Ведение переговоров',
#  'Активные продажи',
#  'Навыки продаж',
#  'React Native',
#  'Android',
#  'iOS',
#  'Big Data',
#  'Oracle BI',
#  'SQL',
#  'ORACLE',
#  'Базы данных',
#  'Аналитика БД',
#  'Подбор персонала',
#  'Поиск персонала в открытых источниках',
#  'Оценка кандидатов',
#  'Прямой поиск',
#  'Рекрутмент',
#  'C++',
#  'Python',
#  'ООП',
#  'SQL',
#  'Linux',
#  'Английский язык',
#  'Тайм-менеджмент',
#  'Управление временем',
#  'Многозадачность',
#  'Управление продуктом',
#  'Agile Project Management',
#  'Управление интернет-проектами',
#  'Управление проектами',
#  'Английский язык',
#  'Грамотность',
#  'Бизнес-анализ',
#  'Сбор и анализ информации',
#  'Поиск и привлечение клиентов',
#  'Активные продажи',
#  'Digital Marketing',
#  'Пользователь ПК',
#  'Грамотная речь',
#  'Работа в команде',
#  'Computer Vision',
#  'Data Scientist',
#  'Atlassian Jira',
#  'DWH',
#  'ETL',
#  'ELT',
#  'Databases',
#  'Data Analysis',
#  'Big Data',
#  'Data Lake',
#  'SQL',
#  'Управление командой',
#  'Аналитическое мышление',
#  'Деловая коммуникация',
#  'Бизнес-анализ',
#  'Управление временем',
#  'Анализ данных',
#  '1С: Предприятие',
#  'Администрирование',
#  'Техническая поддержка',
#  'Администрирование серверов Windows',
#  'SQL',
#  'data.table',
#  'data science',
#  'A/B тесты',
#  'Python',
#  'Аналитическое мышление',
#  'Анализ данных',
#  'ETL',
#  'Прогнозирование',
#  'Python',
#  'SQL',
#  'Tableau',
#  'Machine Learning',
#  'Data Analysis',
#  'Data Science',
#  'Git',
#  'Анализ данных',
#  'Машинное обучение',
#  'PostgreSQL',
#  'Статистический анализ',
#  'Big Data',
#  'Алгоритмы',
#  'Airflow',
#  'Математический анализ',
#  'Работа с базами данных',
#  'Грамотная речь',
#  'Работа с базами данных',
#  'Работа с большим объемом информации',
#  'Умение работать в коллективе',
#  'Работа с существующей базой клиентов',
#  'Претензионная работа с клиентами, работа с возражениями',
#  'SQL',
#  'Аналитика продаж',
#  'Анализ трафика',
#  'Интернет-реклама',
#  'Ретаргетинг',
#  'clickhouse',
#  'predictive models',
#  'ml',
#  'data science',
#  'Машинное обучение',
#  'Machine Learning',
#  'ML',
#  'Python',
#  'C++',
#  'OpenCV',
#  'Нейронные сети',
#  'Data Science',
#  'Математический анализ',
#  'Математический склад ума',
#  'Бизнес-аналитика',
#  'Бизнес-анализ',
#  'Реинжиниринг бизнес-процессов',
#  'Постановка задач разработчикам',
#  'руководство командой разработчиков',
#  'Управление персоналом',
#  'Управление командой',
#  'Обучение и развитие',
#  'Активные продажи',
#  'Деловая коммуникация',
#  'Организаторские навыки',
#  'Онлайн-образование',
#  'Навыки продаж',
#  'Телефонные переговоры',
#  'Проведение презентаций',
#  'Big Data',
#  'Data Science',
#  'Machine Learning',
#  'Python',
#  'ML',
#  'Машинное обучение',
#  'Высокие коммуникативные навыки',
#  'Управление командой',
#  'Scikit-learn',
#  'Kafka',
#  'Pandas',
#  'CI/CD',
#  'Алгоритмы',
#  'Лидерство',
#  'Kubernetes',
#  'Airflow',
#  'Коммуникабельность',
#  'Управленческие навыки',
#  'Мотивация персонала',
#  'Организаторские навыки',
#  'Python',
#  'NLP',
#  'PyTorch',
#  'SpeechBrain',
#  'Организаторские навыки',
#  'Руководство коллективом',
#  'Управление командой',
#  'Планирование',
#  '1С программирование',
#  'Управление продажами',
#  'Управленческие навыки',
#  'Анализ данных',
#  'RTB',
#  'Programmatic',
#  'Data Analysis',
#  'SQL',
#  'SCALA',
#  'Spark',
#  'Hadoop',
#  'Hive',
#  'Python',
#  'Airflow',
#  'Руководство коллективом',
#  'SQL',
#  'Мотивация персонала',
#  '1С программирование',
#  'Бизнес-анализ',
#  'Бюджетирование',
#  'Python',
#  'Аналитическое мышление',
#  'Data Analysis',
#  'MySQL',
#  'ETL',
#  'AWS',
#  'azure',
#  'google cloud',
#  'Agile Project Management',
#  'data ops',
#  'SQL',
#  'Spark',
#  'Python',
#  'Руководство коллективом',
#  'SQL',
#  'Мотивация персонала',
#  '1С программирование',
#  'Бизнес-анализ',
#  'Бюджетирование',
#  'ERP',
#  'Agile Project Management',
#  'Управление проектами',
#  'MS SQL',
#  'PMBOK',
#  'ERP-системы на базе 1С',
#  'Проектный менеджмент',
#  'Управление командой',
#  'Python',
#  'NLP',
#  'PyTorch',
#  'SpeechBrain',
#  'Работа с базами данных',
#  'Работа с существующей базой клиентов',
#  'Стремление к профессиональному росту',
#  'Оператор call-центра',
#  'Консультирование',
#  'C#',
#  'Unity',
#  'Android',
#  'Git',
#  'ООП',
#  'NET Framework',
#  'MVC',
#  'MS Visual Studio',
#  'SQL',
#  'iOS',
#  'Visual Studio C#',
#  'C++',
#  'C/C++',
#  'Computer Vision',
#  'Machine Learning',
#  'Data Science',
#  'Python',
#  'Математическая статистика',
#  'Теория машинного обучения',
#  'scipy',
#  'Deep Learning',
#  'Нейронные сети',
#  'VR',
#  'AR',
#  'Поиск и привлечение клиентов',
#  'B2B Продажи',
#  'Деловое общение',
#  'Заключение договоров',
#  'Навыки переговоров',
#  'Активные продажи',
#  'Работа с большим объемом информации',
#  'Подбор персонала',
#  'Поиск персонала в открытых источниках',
#  'проведение интервью',
#  'Первичная адаптация',
#  'Кадровое делопроизводство',
#  'B2B Продажи',
#  'Проведение презентаций',
#  'Поиск и привлечение клиентов',
#  'Активные продажи',
#  'Холодные продажи',
#  'MS Excel',
#  'Экономический анализ',
#  'Расчет себестоимости',
#  'Финансовая отчетность',
#  'Python',
#  'FastAPI',
#  'Docker',
#  'Python',
#  'Аналитическое мышление',
#  'Data Analysis',
#  'MySQL',
#  'ETL',
#  'AWS',
#  'azure',
#  'google cloud',
#  'Agile Project Management',
#  'data ops',
#  'Активные продажи',
#  'Телефонные переговоры',
#  'Клиентоориентированность',
#  'Оценка потребностей клиентов',
#  'теплая база',
#  'Телемаркетинг',
#  'Развитие продаж',
#  'Техническая поддержка',
#  'Active Directory',
#  'Информационные технологии',
#  'Администрирование',
#  'Настройка ПК',
#  'MS Office',
#  'Symantec Antivirus',
#  'SMTP/POP3/IMAP',
#  'TCP/IP',
#  'DHCP',
#  'SQL',
#  'Python',
#  'Spark',
#  'Airflow',
#  'SCALA',
#  'Hadoop',
#  'Hive',
#  'ETL',
#  'DWH',
#  'Python',
#  'PyTorch',
#  'SQL',
#  'Machine Learning',
#  'Анализ данных',
#  'data science',
#  'numpy',
#  'scipy',
#  'pandas',
#  'lightgbm',
#  'pytorch',
#  'scikit-learn',
#  'neural nets',
#  'nlp',
#  'search ranking',
#  'recommender systems',
#  'a/b-experiments',
#  'hadoop',
#  'hive',
#  'presto',
#  'Mathematics',
#  'Организация учебного процесса',
#  'MySQL',
#  'Atlassian Jira',
#  'Python',
#  'Git',
#  'Дистанционное обучение',
#  'Pandas',
#  'Docker',
#  'Pytest',
#  'Публичные выступления',
#  'Pl/Python',
#  'Data Analysis',
#  'Математический анализ',
#  'Алгоритмы',
#  'Навыки презентации',
#  'Лидерские качества',
#  'Веб-программирование',
#  'Big Data',
#  'Data Mining',
#  'ML',
#  'Jupiter',
#  'MATLAB',
#  'Mathcad',
#  'Data Scientist',
#  'Машинное обучение',
#  'Научные исследования',
#  'Machine Learning',
#  'Numpy',
#  'E-Learning',
#  'Deep Learning',
#  'Работа с базами данных',
#  'Работа с существующей базой клиентов',
#  'Стремление к профессиональному росту',
#  'Владение компьютером',
#  'Грамотная речь',
#  'Пользователь ПК',
#  'Оператор call-центра',
#  'специалист контактного центра',
#  'Консультирование',
#  '1С-Рарус',
#  '1С: Предприятие 8',
#  'Руководство коллективом',
#  'SQL',
#  'Мотивация персонала',
#  '1С программирование',
#  'Бизнес-анализ',
#  'Бюджетирование',
#  'Бизнес-анализ',
#  'Scrum',
#  'Системный анализ',
#  'Big Data',
#  'Управление проектами',
#  'Платежи / Переводы',
#  'B2B Продажи',
#  'Лидогенерация',
#  'Активные продажи',
#  'Телефонные переговоры',
#  'Клиентоориентированность',
#  'Холодные продажи',
#  'Оценка потребностей клиентов',
#  'Python',
#  'NLP',
#  'PyTorch',
#  'SpeechBrain',
#  'Python',
#  'SQL',
#  'Spark',
#  'ClickHouse',
#  '1С-Рарус',
#  '1С: Предприятие 8',
#  'Английский язык',
#  'Ведение переписки на иностранном языке',
#  'Аналитическое мышление',
#  'Обучение',
#  'Технический перевод',
#  'Python',
#  'PyTorch',
#  'NLP',
#  'SQL',
#  'Data Science',
#  'Speech',
#  'Ner',
#  'SMM',
#  'Cоциальный маркетинг',
#  'HTML',
#  'CSS',
#  'Email маркетинг',
#  'Социальные сети',
#  'CRM',
#  'Грамотная речь и письмо',
#  'Удаленная работа',
#  'Python',
#  'PyTorch',
#  'NLP',
#  'SQL',
#  'Data Science',
#  'Speech',
#  'Ner',
#  'Работа в команде',
#  'Ведение отчетности',
#  'MS SQL',
#  'PostgreSQL',
#  'Python',
#  'SCALA',
#  'Azure',
#  'Spark',
#  'ETL',
#  'Английский язык',
#  'Работа с базами данных',
#  'исходящие звонки',
#  'Работа с базами данных',
#  'Работа с существующей базой клиентов',
#  'Стремление к профессиональному росту',
#  'Владение компьютером',
#  'Грамотная речь',
#  'Пользователь ПК',
#  'Оператор call-центра',
#  'специалист контактного центра',
#  'Консультирование',
#  'Python',
#  'PyTorch',
#  'NLP',
#  'SQL',
#  'Data Science',
#  'Speech',
#  'Ner',
#  'upwork',
#  'Разработка ПО',
#  'Аутсорсинг',
#  'B2B Продажи',
#  'Английский язык',
#  'Активные продажи',
#  'Поиск и привлечение клиентов',
#  'Лидогенерация',
#  'Работа с базами данных',
#  'Работа с существующей базой клиентов',
#  'Стремление к профессиональному росту',
#  'Владение компьютером',
#  'Грамотная речь',
#  'Пользователь ПК',
#  'Оператор call-центра',
#  'специалист контактного центра',
#  'Консультирование',
#  'Оператор',
#  'исходящие звонки',
#  'Node.js',
#  'TypeScript',
#  'PostgreSQL',
#  'Microservices',
#  'Google Cloud Platform',
#  'Python',
#  'Аналитическое мышление',
#  'Data Analysis',
#  'MySQL',
#  'ETL',
#  'AWS',
#  'azure',
#  'google cloud',
#  'Agile Project Management',
#  'data ops',
#  'Управление проектами',
#  'Scrum',
#  'Управление рисками',
#  'Аналитическое мышление',
#  'Грамотная речь',
#  'Проведение презентаций',
#  'Управление командой',
#  'PMBOK',
#  'Управление ресурсами',
#  'MS Project',
#  'Kanban',
#  'ML',
#  'CNN',
#  'ITIL',
#  'ITSM',
#  'Python',
#  'Аналитическое мышление',
#  'Data Analysis',
#  'MySQL',
#  'ETL',
#  'AWS',
#  'azure',
#  'google cloud',
#  'Agile Project Management',
#  'data ops',
#  'Python',
#  'Аналитическое мышление',
#  'Data Analysis',
#  'MySQL',
#  'ETL',
#  'AWS',
#  'azure',
#  'google cloud',
#  'Agile Project Management',
#  'data ops',
#  'Расчет заработной платы',
#  'Расчет зарплаты',
#  'Бухгалтерская отчетность',
#  'расчет командировочных',
#  'Подготовка отчетов',
#  '1С: Бухгалтерия',
#  'Расчет затрат',
#  'Python',
#  'Аналитическое мышление',
#  'Data Analysis',
#  'MySQL',
#  'ETL',
#  'AWS',
#  'azure',
#  'google cloud',
#  'Agile Project Management',
#  'data ops',
#  'Python',
#  'Аналитическое мышление',
#  'Data Analysis',
#  'MySQL',
#  'ETL',
#  'AWS',
#  'azure',
#  'google cloud',
#  'Agile Project Management',
#  'data ops']

# %%
Counter(df['key_skills'].sum()).most_common(15)
# Out:
# [('Python', 37),
#  ('SQL', 27),
#  ('Аналитическое мышление', 16),
#  ('Data Analysis', 12),
#  ('Анализ данных', 11),
#  ('Работа с базами данных', 11),
#  ('ETL', 11),
#  ('MySQL', 10),
#  ('Git', 9),
#  ('Английский язык', 9),
#  ('Бизнес-анализ', 9),
#  ('Agile Project Management', 9),
#  ('Грамотная речь', 8),
#  ('Big Data', 8),
#  ('NLP', 8)]

# %%
df[['salary_from', 'salary_to']].describe()
# Out:
#        salary_from  salary_to
# count       106.00      63.00
# mean    150,718.40 234,171.43
# std     122,098.93 166,547.08
# min      30,000.00  30,000.00
# 25%      50,000.00 100,000.00
# 50%     100,000.00 150,000.00
# 75%     200,000.00 390,000.00
# max     400,000.00 550,000.00

# %%
with pd.option_context('display.max_colwidth', None):
    display(df[df['salary_from'] == df['salary_from'].max()])
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# 68                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     <p>Pygmalion AI — это передовая AI-платформа для создания, публикации и продвижения контента в социальных медиа. Для достижения этой цели мы ищем Старшего инженера по данным, который будет играть ключевую роль во внедрении практик DataOps для эффективного управления данными социальных медиа. В этой роли подразумевается контроль за всем жизненным циклом данных, обеспечение целостности данных и расширение возможностей нашей AI-платформы для обеспечения исключительного пользовательского опыта.</p> <p>Ключевые обязанности:</p> <ul> <li>Проектирование, разработка и поддержание надежных и масштабируемых конвейеров данных для сбора, обработки и хранения данных из различных источников социальных медиа и пользовательских взаимодействий.</li> <li>Проектирование хранилища данных.</li> <li>Реализация строгих проверок качества данных и процессов валидации для поддержания целостности, точности и надежности данных социальных медиа, используемых нашими AI-моделями.</li> <li>Автоматизация процессов извлечения, трансформации и загрузки (ETL) для оптимизации загрузки и трансформации данных, уменьшения ручного вмешательства и повышения эффективности.</li> <li>Непрерывный мониторинг и оптимизация конвейеров данных для улучшения скорости, надежности и масштабируемости, обеспечивая бесшовную работу нашего AI-ассистента.</li> <li>Тесное сотрудничество с инженерами машинного обучения и межфункциональными командами для понимания требований к данным и предоставления необходимой инфраструктуры данных для разработки и обучения моделей.</li> <li>Проведение практик управления данными, гарантирование конфиденциальности данных, безопасности и соответствия соответствующим нормативам, включая GDPR, в контексте данных социальных медиа.</li> <li>Установление показателей производительности и внедрение решений мониторинга для выявления и устранения узких мест или аномалий в конвейере данных.</li> <li>Сотрудничество с аналитиками данных и бизнес-командами для проектирования интерактивных панелей инструментов, которые обеспечивают принятие решений на основе данных.</li> <li>Разработка и поддержка датамартов и панелей инструментов, предоставляющих оперативные аналитические данные по данным социальных медиа.</li> <li>Быть в курсе появляющихся технологий, инструментов и фреймворков в области данных, оценивая их потенциал для улучшения процессов инженерии данных.</li> </ul> <p> </p> <p>Требования к кандидату:</p> <ul> <li>Степень бакалавра или магистра по компьютерным наукам, инженерии данных или смежной области.</li> <li>Доказанный опыт работы в области инженерии данных, с акцентом на процессы ETL, разработку конвейеров данных и обеспечение качества данных.</li> <li>Высокая профессиональная компетенция в языках программирования, таких как Python, SQL, а также знание библиотек и фреймворков инженерии данных.</li> <li>Опыт работы с облачными решениями для хранения и обработки данных, такими как AWS, Azure или Goog ...
# 81                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     <p>Pygmalion AI — это передовая AI-платформа для создания, публикации и продвижения контента в социальных медиа. Для достижения этой цели мы ищем Старшего инженера по данным, который будет играть ключевую роль во внедрении практик DataOps для эффективного управления данными социальных медиа. В этой роли подразумевается контроль за всем жизненным циклом данных, обеспечение целостности данных и расширение возможностей нашей AI-платформы для обеспечения исключительного пользовательского опыта.</p> <p>Ключевые обязанности:</p> <ul> <li>Проектирование, разработка и поддержание надежных и масштабируемых конвейеров данных для сбора, обработки и хранения данных из различных источников социальных медиа и пользовательских взаимодействий.</li> <li>Проектирование хранилища данных.</li> <li>Реализация строгих проверок качества данных и процессов валидации для поддержания целостности, точности и надежности данных социальных медиа, используемых нашими AI-моделями.</li> <li>Автоматизация процессов извлечения, трансформации и загрузки (ETL) для оптимизации загрузки и трансформации данных, уменьшения ручного вмешательства и повышения эффективности.</li> <li>Непрерывный мониторинг и оптимизация конвейеров данных для улучшения скорости, надежности и масштабируемости, обеспечивая бесшовную работу нашего AI-ассистента.</li> <li>Тесное сотрудничество с инженерами машинного обучения и межфункциональными командами для понимания требований к данным и предоставления необходимой инфраструктуры данных для разработки и обучения моделей.</li> <li>Проведение практик управления данными, гарантирование конфиденциальности данных, безопасности и соответствия соответствующим нормативам, включая GDPR, в контексте данных социальных медиа.</li> <li>Установление показателей производительности и внедрение решений мониторинга для выявления и устранения узких мест или аномалий в конвейере данных.</li> <li>Сотрудничество с аналитиками данных и бизнес-командами для проектирования интерактивных панелей инструментов, которые обеспечивают принятие решений на основе данных.</li> <li>Разработка и поддержка датамартов и панелей инструментов, предоставляющих оперативные аналитические данные по данным социальных медиа.</li> <li>Быть в курсе появляющихся технологий, инструментов и фреймворков в области данных, оценивая их потенциал для улучшения процессов инженерии данных.</li> </ul> <p> </p> <p>Требования к кандидату:</p> <ul> <li>Степень бакалавра или магистра по компьютерным наукам, инженерии данных или смежной области.</li> <li>Доказанный опыт работы в области инженерии данных, с акцентом на процессы ETL, разработку конвейеров данных и обеспечение качества данных.</li> <li>Высокая профессиональная компетенция в языках программирования, таких как Python, SQL, а также знание библиотек и фреймворков инженерии данных.</li> <li>Опыт работы с облачными решениями для хранения и обработки данных, такими как AWS, Azure или Goog ...
# 102  <p>Контур — экосистема для бизнеса. Каждая четвертая компания в стране решает бизнес-задачи, используя наши сервисы. Мы автоматизируем документооборот, бухгалтерию и отчетность. Делаем эти процессы простыми и быстрыми, а сервисы — удобными для клиента.</p> <p>Центр искусственного интеллекта в Контуре помогает зарабатывать деньги за счет технологий машинного обучения и больших данных. Например, чат-бот Сирена экономит около 25% времени консультантов техподдержки в чатах, а технология распознавания речи обрабатывает тысячи лет записей каждый год. Мы постоянно следим за прогрессом в технологиях и разрабатываем новые методы и алгоритмы, чтобы сделать инновации доступными для использования в продуктах и процессах компании.</p> <p>В Центре искусственного интеллекта представлены разные роли: есть Data Scientist, разработчики и аналитики данных, DevOps-инженеры, QA-специалисты, системные аналитики, product- и project-менеджеры. Свое железо (V100/A100) и асессорская служба позволяют нам не ограничивать себя при работе с чувствительными данными. А крутая инфраструктурная команда создает, улучшает и развивает инструменты MLOps на любой вкус от ресерча до прода. Ищем эксперта, чтобы реализовывать и внедрять SOTA-подходы в наши сервисы.</p> <p>В лаборатории «Speech&amp;NLP» Центра искусственного интеллекта команда (7 ML Research Engineer) запустила с нуля и масштабировала на всю компанию собственный ASR, сэкономив сотни миллионов рублей в год. Сейчас, например, мы хотим аналогично создать и внедрить Text To Speech.</p> <p><strong>Чем предстоит заниматься</strong></p> <p><em>Концептуально:</em></p> <ul> <li> <p>Взять на себя определенное направление технологий (или несколько).</p> </li> <li> <p>Сформулировать видение его развития и актуализировать его своевременно, исходя из внутренних или внешних изменений.</p> </li> <li> <p>Планировать последовательность задач и помогать другим участникам лаборатории участвовать в его развитии, т. е. делать задачки и привносить что-то от себя в планы.</p> </li> <li> <p>Участвовать в разработке других технологий, помимо своего направления: ревью, небольшие задачи, обсуждения.</p> </li> </ul> <p><em>На испытательный срок поставим цель:</em></p> <ul> <li> <p>Погрузиться в одну из технологий.</p> </li> <li> <p>Понять, где мы сейчас.</p> </li> <li> <p>Уточнить, куда идем.</p> </li> <li> <p>Подготовить план развития с перспективой примерно на год.</p> </li> </ul> <p><em>Примеры задач (могут меняться в зависимости от вашего опыта и новостей мира технологий):</em></p> <ul> <li> <p>Разделение аудио на нескольких говорящих.</p> </li> <li> <p>Voice cloning.</p> </li> <li> <p>Улучшение текущего решения ASR.</p> </li> <li> <p>Поддержка и расширение набора NLP технологий: NER, sentiment analysis, spelling correction и другие.</p> </li> </ul> <p><strong>Наши ожидания</strong></p> <ul> <li> <p>Отличное понимание текущего состояния области Speech/NLP: следите за свежими статьями и SOTA по технологиям и делитесь с командой.</p> </li> <li> <p>Глубокое понимание PyTorch: сможете при необходимости быстро провести эксперименты, править архитектуру и разобраться в коде коллег.</p> </li> <li> <p>Умение рассказывать сложные вещи простым языком: кроме Data Scientist, в команде есть product- и project-менеджеры, разработчики, аналитики.</p> </li> </ul> <p><strong>Дополнительным плюсом будет</strong></p> <ul> <li> <p>Знание и практический опыт с transformers, fairseq, Nemo, SpeechBrain, ONNX/TorchScript.</p> </li> <li> <p>Знание методов обработки сигналов.</p> </li> <li> <p>Опыт оптимизации / дистилляции DL-моделей для продакшена.</p> </li> <li> <p>Публикации или блогпосты в области Speech/NLP.</p> </li> </ul> <p><strong>Мы предлагаем</strong></p> <ul> <li> <p>Оклад от 350 до 470 тысяч рублей на руки, точная сумма зависит от ваших компетенций и растет по итогам ревью. Кроме оклада есть внутригодовые премии за выполнение целей — 2-3 оклада в год. С ними ежемесячный доход будет от 400 до 550 тысяч рублей. Цели могут быть похожими ...
# 104  <p>Контур — экосистема для бизнеса. Каждая четвертая компания в стране решает бизнес-задачи, используя наши сервисы. Мы автоматизируем документооборот, бухгалтерию и отчетность. Делаем эти процессы простыми и быстрыми, а сервисы — удобными для клиента.</p> <p>Центр искусственного интеллекта в Контуре помогает зарабатывать деньги за счет технологий машинного обучения и больших данных. Например, чат-бот Сирена экономит около 25% времени консультантов техподдержки в чатах, а технология распознавания речи обрабатывает тысячи лет записей каждый год. Мы постоянно следим за прогрессом в технологиях и разрабатываем новые методы и алгоритмы, чтобы сделать инновации доступными для использования в продуктах и процессах компании.</p> <p>В Центре искусственного интеллекта представлены разные роли: есть Data Scientist, разработчики и аналитики данных, DevOps-инженеры, QA-специалисты, системные аналитики, product- и project-менеджеры. Свое железо (V100/A100) и асессорская служба позволяют нам не ограничивать себя при работе с чувствительными данными. А крутая инфраструктурная команда создает, улучшает и развивает инструменты MLOps на любой вкус от ресерча до прода. Ищем эксперта, чтобы реализовывать и внедрять SOTA-подходы в наши сервисы.</p> <p>В лаборатории «Speech&amp;NLP» Центра искусственного интеллекта команда (7 ML Research Engineer) запустила с нуля и масштабировала на всю компанию собственный ASR, сэкономив сотни миллионов рублей в год. Сейчас, например, мы хотим аналогично создать и внедрить Text To Speech.</p> <p><strong>Чем предстоит заниматься</strong></p> <p><em>Концептуально:</em></p> <ul> <li> <p>Взять на себя определенное направление технологий (или несколько).</p> </li> <li> <p>Сформулировать видение его развития и актуализировать его своевременно, исходя из внутренних или внешних изменений.</p> </li> <li> <p>Планировать последовательность задач и помогать другим участникам лаборатории участвовать в его развитии, т. е. делать задачки и привносить что-то от себя в планы.</p> </li> <li> <p>Участвовать в разработке других технологий, помимо своего направления: ревью, небольшие задачи, обсуждения.</p> </li> </ul> <p><em>На испытательный срок поставим цель:</em></p> <ul> <li> <p>Погрузиться в одну из технологий.</p> </li> <li> <p>Понять, где мы сейчас.</p> </li> <li> <p>Уточнить, куда идем.</p> </li> <li> <p>Подготовить план развития с перспективой примерно на год.</p> </li> </ul> <p><em>Примеры задач (могут меняться в зависимости от вашего опыта и новостей мира технологий):</em></p> <ul> <li> <p>Разделение аудио на нескольких говорящих.</p> </li> <li> <p>Voice cloning.</p> </li> <li> <p>Улучшение текущего решения ASR.</p> </li> <li> <p>Поддержка и расширение набора NLP технологий: NER, sentiment analysis, spelling correction и другие.</p> </li> </ul> <p><strong>Наши ожидания</strong></p> <ul> <li> <p>Отличное понимание текущего состояния области Speech/NLP: следите за свежими статьями и SOTA по технологиям и делитесь с командой.</p> </li> <li> <p>Глубокое понимание PyTorch: сможете при необходимости быстро провести эксперименты, править архитектуру и разобраться в коде коллег.</p> </li> <li> <p>Умение рассказывать сложные вещи простым языком: кроме Data Scientist, в команде есть product- и project-менеджеры, разработчики, аналитики.</p> </li> </ul> <p><strong>Дополнительным плюсом будет</strong></p> <ul> <li> <p>Знание и практический опыт с transformers, fairseq, Nemo, SpeechBrain, ONNX/TorchScript.</p> </li> <li> <p>Знание методов обработки сигналов.</p> </li> <li> <p>Опыт оптимизации / дистилляции DL-моделей для продакшена.</p> </li> <li> <p>Публикации или блогпосты в области Speech/NLP.</p> </li> </ul> <p><strong>Мы предлагаем</strong></p> <ul> <li> <p>Оклад от 350 до 470 тысяч рублей на руки, точная сумма зависит от ваших компетенций и растет по итогам ревью. Кроме оклада есть внутригодовые премии за выполнение целей — 2-3 оклада в год. С ними ежемесячный доход будет от 400 до 550 тысяч рублей. Цели могут быть похожими ...
# 106                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       <p><strong>Responsibilities:</strong></p> <p>Performance Marketing/CRM/Loyalty programs, Analytics, Data science:</p> <p>· Leadership of a team (8-10 ppl): processes, effectiveness, staffing the team, supervision.</p> <p>· Development of CRM strategy/Loyalty programs.</p> <p>· Supervision of w ...
# 110  <p>Контур — экосистема для бизнеса. Каждая четвертая компания в стране решает бизнес-задачи, используя наши сервисы. Мы автоматизируем документооборот, бухгалтерию и отчетность. Делаем эти процессы простыми и быстрыми, а сервисы — удобными для клиента.</p> <p>Центр искусственного интеллекта в Контуре помогает зарабатывать деньги за счет технологий машинного обучения и больших данных. Например, чат-бот Сирена экономит около 25% времени консультантов техподдержки в чатах, а технология распознавания речи обрабатывает тысячи лет записей каждый год. Мы постоянно следим за прогрессом в технологиях и разрабатываем новые методы и алгоритмы, чтобы сделать инновации доступными для использования в продуктах и процессах компании.</p> <p>В Центре искусственного интеллекта представлены разные роли: есть Data Scientist, разработчики и аналитики данных, DevOps-инженеры, QA-специалисты, системные аналитики, product- и project-менеджеры. Свое железо (V100/A100) и асессорская служба позволяют нам не ограничивать себя при работе с чувствительными данными. А крутая инфраструктурная команда создает, улучшает и развивает инструменты MLOps на любой вкус от ресерча до прода. Ищем эксперта, чтобы реализовывать и внедрять SOTA-подходы в наши сервисы.</p> <p>В лаборатории «Speech&amp;NLP» Центра искусственного интеллекта команда (7 ML Research Engineer) запустила с нуля и масштабировала на всю компанию собственный ASR, сэкономив сотни миллионов рублей в год. Сейчас, например, мы хотим аналогично создать и внедрить Text To Speech.</p> <p><strong>Чем предстоит заниматься</strong></p> <p><em>Концептуально:</em></p> <ul> <li> <p>Взять на себя определенное направление технологий (или несколько).</p> </li> <li> <p>Сформулировать видение его развития и актуализировать его своевременно, исходя из внутренних или внешних изменений.</p> </li> <li> <p>Планировать последовательность задач и помогать другим участникам лаборатории участвовать в его развитии, т. е. делать задачки и привносить что-то от себя в планы.</p> </li> <li> <p>Участвовать в разработке других технологий, помимо своего направления: ревью, небольшие задачи, обсуждения.</p> </li> </ul> <p><em>На испытательный срок поставим цель:</em></p> <ul> <li> <p>Погрузиться в одну из технологий.</p> </li> <li> <p>Понять, где мы сейчас.</p> </li> <li> <p>Уточнить, куда идем.</p> </li> <li> <p>Подготовить план развития с перспективой примерно на год.</p> </li> </ul> <p><em>Примеры задач (могут меняться в зависимости от вашего опыта и новостей мира технологий):</em></p> <ul> <li> <p>Разделение аудио на нескольких говорящих.</p> </li> <li> <p>Voice cloning.</p> </li> <li> <p>Улучшение текущего решения ASR.</p> </li> <li> <p>Поддержка и расширение набора NLP технологий: NER, sentiment analysis, spelling correction и другие.</p> </li> </ul> <p><strong>Наши ожидания</strong></p> <ul> <li> <p>Отличное понимание текущего состояния области Speech/NLP: следите за свежими статьями и SOTA по технологиям и делитесь с командой.</p> </li> <li> <p>Глубокое понимание PyTorch: сможете при необходимости быстро провести эксперименты, править архитектуру и разобраться в коде коллег.</p> </li> <li> <p>Умение рассказывать сложные вещи простым языком: кроме Data Scientist, в команде есть product- и project-менеджеры, разработчики, аналитики.</p> </li> </ul> <p><strong>Дополнительным плюсом будет</strong></p> <ul> <li> <p>Знание и практический опыт с transformers, fairseq, Nemo, SpeechBrain, ONNX/TorchScript.</p> </li> <li> <p>Знание методов обработки сигналов.</p> </li> <li> <p>Опыт оптимизации / дистилляции DL-моделей для продакшена.</p> </li> <li> <p>Публикации или блогпосты в области Speech/NLP.</p> </li> </ul> <p><strong>Мы предлагаем</strong></p> <ul> <li> <p>Оклад от 350 до 470 тысяч рублей на руки, точная сумма зависит от ваших компетенций и растет по итогам ревью. Кроме оклада есть внутригодовые премии за выполнение целей — 2-3 оклада в год. С ними ежемесячный доход будет от 400 до 550 тысяч рублей. Цели могут быть похожими ...
# 114                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    <p>Pygmalion AI — это передовая AI-платформа для создания, публикации и продвижения контента в социальных медиа. Для достижения этой цели мы ищем Старшего инженера по данным, который будет играть ключевую роль во внедрении практик DataOps для эффективного управления данными социальных медиа. В этой роли подразумевается контроль за всем жизненным циклом данных, обеспечение целостности данных и расширение возможностей нашей AI-платформы для обеспечения исключительного пользовательского опыта.</p> <p>Ключевые обязанности:</p> <ul> <li>Проектирование, разработка и поддержание надежных и масштабируемых конвейеров данных для сбора, обработки и хранения данных из различных источников социальных медиа и пользовательских взаимодействий.</li> <li>Проектирование хранилища данных.</li> <li>Реализация строгих проверок качества данных и процессов валидации для поддержания целостности, точности и надежности данных социальных медиа, используемых нашими AI-моделями.</li> <li>Автоматизация процессов извлечения, трансформации и загрузки (ETL) для оптимизации загрузки и трансформации данных, уменьшения ручного вмешательства и повышения эффективности.</li> <li>Непрерывный мониторинг и оптимизация конвейеров данных для улучшения скорости, надежности и масштабируемости, обеспечивая бесшовную работу нашего AI-ассистента.</li> <li>Тесное сотрудничество с инженерами машинного обучения и межфункциональными командами для понимания требований к данным и предоставления необходимой инфраструктуры данных для разработки и обучения моделей.</li> <li>Проведение практик управления данными, гарантирование конфиденциальности данных, безопасности и соответствия соответствующим нормативам, включая GDPR, в контексте данных социальных медиа.</li> <li>Установление показателей производительности и внедрение решений мониторинга для выявления и устранения узких мест или аномалий в конвейере данных.</li> <li>Сотрудничество с аналитиками данных и бизнес-командами для проектирования интерактивных панелей инструментов, которые обеспечивают принятие решений на основе данных.</li> <li>Разработка и поддержка датамартов и панелей инструментов, предоставляющих оперативные аналитические данные по данным социальных медиа.</li> <li>Быть в курсе появляющихся технологий, инструментов и фреймворков в области данных, оценивая их потенциал для улучшения процессов инженерии данных.</li> </ul> <p> </p> <p>Требования к кандидату:</p> <ul> <li>Степень бакалавра или магистра по компьютерным наукам, инженерии данных или смежной области.</li> <li>Доказанный опыт работы в области инженерии данных, с акцентом на процессы ETL, разработку конвейеров данных и обеспечение качества данных.</li> <li>Высокая профессиональная компетенция в языках программирования, таких как Python, SQL, а также знание библиотек и фреймворков инженерии данных.</li> <li>Опыт работы с облачными решениями для хранения и обработки данных, такими как AWS, Azure или Goog ...
# 117                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    <p>Pygmalion AI — это передовая AI-платформа для создания, публикации и продвижения контента в социальных медиа. Для достижения этой цели мы ищем Старшего инженера по данным, который будет играть ключевую роль во внедрении практик DataOps для эффективного управления данными социальных медиа. В этой роли подразумевается контроль за всем жизненным циклом данных, обеспечение целостности данных и расширение возможностей нашей AI-платформы для обеспечения исключительного пользовательского опыта.</p> <p>Ключевые обязанности:</p> <ul> <li>Проектирование, разработка и поддержание надежных и масштабируемых конвейеров данных для сбора, обработки и хранения данных из различных источников социальных медиа и пользовательских взаимодействий.</li> <li>Проектирование хранилища данных.</li> <li>Реализация строгих проверок качества данных и процессов валидации для поддержания целостности, точности и надежности данных социальных медиа, используемых нашими AI-моделями.</li> <li>Автоматизация процессов извлечения, трансформации и загрузки (ETL) для оптимизации загрузки и трансформации данных, уменьшения ручного вмешательства и повышения эффективности.</li> <li>Непрерывный мониторинг и оптимизация конвейеров данных для улучшения скорости, надежности и масштабируемости, обеспечивая бесшовную работу нашего AI-ассистента.</li> <li>Тесное сотрудничество с инженерами машинного обучения и межфункциональными командами для понимания требований к данным и предоставления необходимой инфраструктуры данных для разработки и обучения моделей.</li> <li>Проведение практик управления данными, гарантирование конфиденциальности данных, безопасности и соответствия соответствующим нормативам, включая GDPR, в контексте данных социальных медиа.</li> <li>Установление показателей производительности и внедрение решений мониторинга для выявления и устранения узких мест или аномалий в конвейере данных.</li> <li>Сотрудничество с аналитиками данных и бизнес-командами для проектирования интерактивных панелей инструментов, которые обеспечивают принятие решений на основе данных.</li> <li>Разработка и поддержка датамартов и панелей инструментов, предоставляющих оперативные аналитические данные по данным социальных медиа.</li> <li>Быть в курсе появляющихся технологий, инструментов и фреймворков в области данных, оценивая их потенциал для улучшения процессов инженерии данных.</li> </ul> <p> </p> <p>Требования к кандидату:</p> <ul> <li>Степень бакалавра или магистра по компьютерным наукам, инженерии данных или смежной области.</li> <li>Доказанный опыт работы в области инженерии данных, с акцентом на процессы ETL, разработку конвейеров данных и обеспечение качества данных.</li> <li>Высокая профессиональная компетенция в языках программирования, таких как Python, SQL, а также знание библиотек и фреймворков инженерии данных.</li> <li>Опыт работы с облачными решениями для хранения и обработки данных, такими как AWS, Azure или Goog ...
# 118                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    <p>Pygmalion AI — это передовая AI-платформа для создания, публикации и продвижения контента в социальных медиа. Для достижения этой цели мы ищем Старшего инженера по данным, который будет играть ключевую роль во внедрении практик DataOps для эффективного управления данными социальных медиа. В этой роли подразумевается контроль за всем жизненным циклом данных, обеспечение целостности данных и расширение возможностей нашей AI-платформы для обеспечения исключительного пользовательского опыта.</p> <p>Ключевые обязанности:</p> <ul> <li>Проектирование, разработка и поддержание надежных и масштабируемых конвейеров данных для сбора, обработки и хранения данных из различных источников социальных медиа и пользовательских взаимодействий.</li> <li>Проектирование хранилища данных.</li> <li>Реализация строгих проверок качества данных и процессов валидации для поддержания целостности, точности и надежности данных социальных медиа, используемых нашими AI-моделями.</li> <li>Автоматизация процессов извлечения, трансформации и загрузки (ETL) для оптимизации загрузки и трансформации данных, уменьшения ручного вмешательства и повышения эффективности.</li> <li>Непрерывный мониторинг и оптимизация конвейеров данных для улучшения скорости, надежности и масштабируемости, обеспечивая бесшовную работу нашего AI-ассистента.</li> <li>Тесное сотрудничество с инженерами машинного обучения и межфункциональными командами для понимания требований к данным и предоставления необходимой инфраструктуры данных для разработки и обучения моделей.</li> <li>Проведение практик управления данными, гарантирование конфиденциальности данных, безопасности и соответствия соответствующим нормативам, включая GDPR, в контексте данных социальных медиа.</li> <li>Установление показателей производительности и внедрение решений мониторинга для выявления и устранения узких мест или аномалий в конвейере данных.</li> <li>Сотрудничество с аналитиками данных и бизнес-командами для проектирования интерактивных панелей инструментов, которые обеспечивают принятие решений на основе данных.</li> <li>Разработка и поддержка датамартов и панелей инструментов, предоставляющих оперативные аналитические данные по данным социальных медиа.</li> <li>Быть в курсе появляющихся технологий, инструментов и фреймворков в области данных, оценивая их потенциал для улучшения процессов инженерии данных.</li> </ul> <p> </p> <p>Требования к кандидату:</p> <ul> <li>Степень бакалавра или магистра по компьютерным наукам, инженерии данных или смежной области.</li> <li>Доказанный опыт работы в области инженерии данных, с акцентом на процессы ETL, разработку конвейеров данных и обеспечение качества данных.</li> <li>Высокая профессиональная компетенция в языках программирования, таких как Python, SQL, а также знание библиотек и фреймворков инженерии данных.</li> <li>Опыт работы с облачными решениями для хранения и обработки данных, такими как AWS, Azure или Goog ...
# 120                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    <p>Pygmalion AI — это передовая AI-платформа для создания, публикации и продвижения контента в социальных медиа. Для достижения этой цели мы ищем Старшего инженера по данным, который будет играть ключевую роль во внедрении практик DataOps для эффективного управления данными социальных медиа. В этой роли подразумевается контроль за всем жизненным циклом данных, обеспечение целостности данных и расширение возможностей нашей AI-платформы для обеспечения исключительного пользовательского опыта.</p> <p>Ключевые обязанности:</p> <ul> <li>Проектирование, разработка и поддержание надежных и масштабируемых конвейеров данных для сбора, обработки и хранения данных из различных источников социальных медиа и пользовательских взаимодействий.</li> <li>Проектирование хранилища данных.</li> <li>Реализация строгих проверок качества данных и процессов валидации для поддержания целостности, точности и надежности данных социальных медиа, используемых нашими AI-моделями.</li> <li>Автоматизация процессов извлечения, трансформации и загрузки (ETL) для оптимизации загрузки и трансформации данных, уменьшения ручного вмешательства и повышения эффективности.</li> <li>Непрерывный мониторинг и оптимизация конвейеров данных для улучшения скорости, надежности и масштабируемости, обеспечивая бесшовную работу нашего AI-ассистента.</li> <li>Тесное сотрудничество с инженерами машинного обучения и межфункциональными командами для понимания требований к данным и предоставления необходимой инфраструктуры данных для разработки и обучения моделей.</li> <li>Проведение практик управления данными, гарантирование конфиденциальности данных, безопасности и соответствия соответствующим нормативам, включая GDPR, в контексте данных социальных медиа.</li> <li>Установление показателей производительности и внедрение решений мониторинга для выявления и устранения узких мест или аномалий в конвейере данных.</li> <li>Сотрудничество с аналитиками данных и бизнес-командами для проектирования интерактивных панелей инструментов, которые обеспечивают принятие решений на основе данных.</li> <li>Разработка и поддержка датамартов и панелей инструментов, предоставляющих оперативные аналитические данные по данным социальных медиа.</li> <li>Быть в курсе появляющихся технологий, инструментов и фреймворков в области данных, оценивая их потенциал для улучшения процессов инженерии данных.</li> </ul> <p> </p> <p>Требования к кандидату:</p> <ul> <li>Степень бакалавра или магистра по компьютерным наукам, инженерии данных или смежной области.</li> <li>Доказанный опыт работы в области инженерии данных, с акцентом на процессы ETL, разработку конвейеров данных и обеспечение качества данных.</li> <li>Высокая профессиональная компетенция в языках программирования, таких как Python, SQL, а также знание библиотек и фреймворков инженерии данных.</li> <li>Опыт работы с облачными решениями для хранения и обработки данных, такими как AWS, Azure или Goog ...
# 121                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    <p>Pygmalion AI — это передовая AI-платформа для создания, публикации и продвижения контента в социальных медиа. Для достижения этой цели мы ищем Старшего инженера по данным, который будет играть ключевую роль во внедрении практик DataOps для эффективного управления данными социальных медиа. В этой роли подразумевается контроль за всем жизненным циклом данных, обеспечение целостности данных и расширение возможностей нашей AI-платформы для обеспечения исключительного пользовательского опыта.</p> <p>Ключевые обязанности:</p> <ul> <li>Проектирование, разработка и поддержание надежных и масштабируемых конвейеров данных для сбора, обработки и хранения данных из различных источников социальных медиа и пользовательских взаимодействий.</li> <li>Проектирование хранилища данных.</li> <li>Реализация строгих проверок качества данных и процессов валидации для поддержания целостности, точности и надежности данных социальных медиа, используемых нашими AI-моделями.</li> <li>Автоматизация процессов извлечения, трансформации и загрузки (ETL) для оптимизации загрузки и трансформации данных, уменьшения ручного вмешательства и повышения эффективности.</li> <li>Непрерывный мониторинг и оптимизация конвейеров данных для улучшения скорости, надежности и масштабируемости, обеспечивая бесшовную работу нашего AI-ассистента.</li> <li>Тесное сотрудничество с инженерами машинного обучения и межфункциональными командами для понимания требований к данным и предоставления необходимой инфраструктуры данных для разработки и обучения моделей.</li> <li>Проведение практик управления данными, гарантирование конфиденциальности данных, безопасности и соответствия соответствующим нормативам, включая GDPR, в контексте данных социальных медиа.</li> <li>Установление показателей производительности и внедрение решений мониторинга для выявления и устранения узких мест или аномалий в конвейере данных.</li> <li>Сотрудничество с аналитиками данных и бизнес-командами для проектирования интерактивных панелей инструментов, которые обеспечивают принятие решений на основе данных.</li> <li>Разработка и поддержка датамартов и панелей инструментов, предоставляющих оперативные аналитические данные по данным социальных медиа.</li> <li>Быть в курсе появляющихся технологий, инструментов и фреймворков в области данных, оценивая их потенциал для улучшения процессов инженерии данных.</li> </ul> <p> </p> <p>Требования к кандидату:</p> <ul> <li>Степень бакалавра или магистра по компьютерным наукам, инженерии данных или смежной области.</li> <li>Доказанный опыт работы в области инженерии данных, с акцентом на процессы ETL, разработку конвейеров данных и обеспечение качества данных.</li> <li>Высокая профессиональная компетенция в языках программирования, таких как Python, SQL, а также знание библиотек и фреймворков инженерии данных.</li> <li>Опыт работы с облачными решениями для хранения и обработки данных, такими как AWS, Azure или Goog ...
#
#                                                                                                                     key_skills  \
# 68   [Python, Аналитическое мышление, Data Analysis, MySQL, ETL, AWS, azure, google cloud, Agile Project Management, data ops]
# 81   [Python, Аналитическое мышление, Data Analysis, MySQL, ETL, AWS, azure, google cloud, Agile Project Management, data ops]
# 102                                                                     [Python, PyTorch, NLP, SQL, Data Science, Speech, Ner]
# 104                                                                     [Python, PyTorch, NLP, SQL, Data Science, Speech, Ner]
# 106                                                                                                                         []
# 110                                                                     [Python, PyTorch, NLP, SQL, Data Science, Speech, Ner]
# 114  [Python, Аналитическое мышление, Data Analysis, MySQL, ETL, AWS, azure, google cloud, Agile Project Management, data ops]
# 117  [Python, Аналитическое мышление, Data Analysis, MySQL, ETL, AWS, azure, google cloud, Agile Project Management, data ops]
# 118  [Python, Аналитическое мышление, Data Analysis, MySQL, ETL, AWS, azure, google cloud, Agile Project Management, data ops]
# 120  [Python, Аналитическое мышление, Data Analysis, MySQL, ETL, AWS, azure, google cloud, Agile Project Management, data ops]
# 121  [Python, Аналитическое мышление, Data Analysis, MySQL, ETL, AWS, azure, google cloud, Agile Project Management, data ops]
#
#      salary_from  salary_to                             url
# 68    400,000.00        NaN  https://hh.ru/vacancy/88412208
# 81    400,000.00        NaN  https://hh.ru/vacancy/88412206
# 102   400,000.00 550,000.00  https://hh.ru/vacancy/89384357
# 104   400,000.00 550,000.00  https://hh.ru/vacancy/89384334
# 106   400,000.00        NaN  https://hh.ru/vacancy/88681004
# 110   400,000.00 550,000.00  https://hh.ru/vacancy/89384325
# 114   400,000.00        NaN  https://hh.ru/vacancy/88412213
# 117   400,000.00        NaN  https://hh.ru/vacancy/88412207
# 118   400,000.00        NaN  https://hh.ru/vacancy/88412212
# 120   400,000.00        NaN  https://hh.ru/vacancy/88412209
# 121   400,000.00        NaN  https://hh.ru/vacancy/88412210

# %% [markdown]
# ## Задание 1
#
# Найдите все вакансии, в которых тип занятости "Волонтер".
# В этом вам поможет поле "employment", в которое подставляются значения из общих словарей: https://api.hh.ru/dictionaries

# %%
# ваш код

# %% [markdown]
# ## Задание 2
#
# Найдите, сколько вакансий на hh было опубликовано за эту неделю.

# %%
# ваш код

# %% [markdown]
# ## Задание 3
#
# Найдите все вакансии, которые сейчас открыты у вашей компании (учебного заведения / интересующей вас компании). Загрузите данные в таблицу и сделайте описательную статистику заработных плат в вакансиях с помощью метода describe().
#
# В этом вам поможет модуль "Поиск работодателя": https://api.hh.ru/openapi/redoc#tag/Rabotodatel/operation/search-employer

# %%
# ваш код
